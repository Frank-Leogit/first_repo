# %%
from PIL import Image
img = Image.open('img/download.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=299x169 at 0x20724E1C2B0>

# %% [markdown]
# ## 1. Matplotlib
# Matplotlib is a very powerful plotting library useful for those working with Python and NumPy. The most used module of Matplotib is Pyplot which provides an interface like MATLAB but instead, it uses Python and it is open source.
#
# [Official Quick-start guide](https://matplotlib.org/stable/tutorials/introductory/usage.html#sphx-glr-tutorials-introductory-usage-py)
